# %% [markdown]
# #### Dictionary Object

# %% [markdown]
# in case of set we are going to use '{}'

# %%
s = {}

# %% [markdown]
# without no data in curly braces , it is recognized as dictionary

# %%
type(s)
# Out:
# dict

# %% [markdown]
# ##### Set Object

# %%
s1 = {1,2,3,4,5}

# %% [markdown]
# Now, this curly braces recognized as set

# %%
type(s1)
# Out:
# set

# %% [markdown]
# see the difference, dictionary and set

# %%
s2 = {1,1,12,3,3,3,4,5,5,5,55,523,34,3,45,6,67}

# %%
s2
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %% [markdown]
# as you can see there no duplicates inside this output, set has removed the duplicates
# - this where usability of set comes into picture
#
# - set is a collection which is used to store a unic set of data, and always try to remove duplicates from our variable, data set

# %% [markdown]
# Q. Can you convert set to list ?

# %%
l = list(s2)
l
# Out:
# [1, 34, 3, 4, 5, 6, 67, 523, 12, 45, 55]

# %% [markdown]
# Q. Can i convert the list back to set ?

# %%
set(l)
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %% [markdown]
# Q. Can you convert set to tuples ?

# %%
 t = tuple(s2)
 t
# Out:
# (1, 34, 3, 4, 5, 6, 67, 523, 12, 45, 55)

# %% [markdown]
# Q. Can we convert tuple back to Set ?

# %%
set(t)
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %% [markdown]
# We are trying to store integer and list inside a set s4, it says no we can't,it says ` unhashable type: 'list' `

# %%
s4 = {1,2,3,4,[1,2,3,4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c88b0db15002> in <cell line: 1>()
# ----> 1 s4 = {1,2,3,4,[1,2,3,4]}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# Reason: in case of a set when ever you try to hold a data for each and every element, because it is trying to find out a unique and it is trying to remove the duplicates, right, so it will try to store the informations by converting your informations with a hashable indexes . and that is a reason it is not allowing us to store a list inside a set.

# %%
s5 = {1,2,3,4, (1,2,3,4)}

# %% [markdown]
# but see, it is allowing us to store tuple inside a set, but it is not allowing us to store a list inside a set.

# %% [markdown]
# Again, the only reason is that, in case of list, i'll be able to make changes, right. i'll be able to mutate indexes , so data or information is mutable only in case of list. but tuples are immutable objects. i won't be able to make any changes it's fixed. and if it is fixed it will be able to make proper hashing indexes.

# %%
s6  = {"Rahul", 'rahul', 2,3,4,5}

# %%
s6
# Out:
# {2, 3, 4, 5, 'Rahul', 'rahul'}

# %% [markdown]
# as you can see we got both in the result, reason: python is case sensitive language. means it is treating upper case and lower case differently.
# it is not same for my compiler. just because of that it is trying keep both.

# %%
s7 = {"rahul", 'rahul', 2,3,4,5}

# %%
s7
# Out:
# {2, 3, 4, 5, 'rahul'}

# %% [markdown]
# As you can see it removed one of it from colelction to maintain uniqueness in collection

# %% [markdown]
# so in this we can know what we can hold inside a set and what we can't hold inside a set

# %%
s7
# Out:
# {2, 3, 4, 5, 'rahul'}

# %% [markdown]
# Q. if someone asked me to extract a data from set, from a particular location/ indexes

# %%
s7[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-02c99effdb87> in <cell line: 1>()
# ----> 1 s7[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# so set is not subscriptable like list and tuples.
# Cause it creates it's own hashable indexes internally
# because of that we can do index based subscripting in set's

# %%
s7[::-1] # performing reverse operation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-56131b1e21e5> in <cell line: 1>()
# ----> 1 s7[::-1] # performing reverse operation
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# - reverse also not possible
# - internaly system is tring to hold information differently
#
# - by converting set to list and then one can subscript this operations but with set not possible

# %%
s7
# Out:
# {2, 3, 4, 5, 'rahul'}

# %%
for  i in s7:
  print(i)
# Out:
# 2
# 3
# 4
# 5
# rahul

# %% [markdown]
# with the help of for loop we can print the hasable type of element which are present inside a set but directly with indexes we can't be able to do it

# %%
 s7
# Out:
# {2, 3, 4, 5, 'rahul'}

# %% [markdown]
# *add()* if a function of set using `add()` we can add an element inside a set

# %%
s7.add(34)

# %%
s7
# Out:
# {2, 3, 34, 4, 5, 'rahul'}

# %% [markdown]
# see it is added 34

# %%
s7.add(2)

# %%
s7
# Out:
# {2, 3, 34, 4, 5, 'rahul'}

# %% [markdown]
# but we know 2 was already there in set, so set will maintain the uniqueness and will not add 2 to set

# %%
len(s7)
# Out:
# 6

# %% [markdown]
# *pop()* is a built-in function of set. it will pop ne of the element from set

# %%
s7.pop()
# Out:
# 2

# %%
s7
# Out:
# {3, 34, 4, 5, 'rahul'}

# %% [markdown]
# - `2` is not available

# %%
s7.pop()
# Out:
# 3

# %%
s7.pop()
# Out:
# 4

# %%
s7.pop()
# Out:
# 5

# %% [markdown]
# - as we can see it is not poping alements in a order

# %%
s7
# Out:
# {34, 'rahul'}

# %% [markdown]
# - so it is poping the elements based on hashing sequence is has created
# - so it will always go for lower hash and then upper hash
# - one by one it will remove all the hashes or extrcat all the infromation from the set

# %% [markdown]
# if we use `clear()`

# %%
s7.clear()

# %%
s7
# Out:
# set()

# %% [markdown]
# - it has cleared the entire `s7` set/ removed all the elements from this set

# %%
s8 = {1,2,3,4}
s9 = {1,2,3,5}

# %%
s8.difference(s9)
# Out:
# {4}

# %% [markdown]
# `{1,2,3,4} - {1,2,3,5}`
# - it removed similar from left set and returned remaing from left set, which is `4`

# %%
# vice-versa
s9.difference(s8)
# Out:
# {5}

# %% [markdown]
# `{1,2,3,5} - {1,2,3,4}`
# - it removed similar from left set and returned remaing from left set, which is `5`
