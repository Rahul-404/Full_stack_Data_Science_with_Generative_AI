# %%
print("this is my program|")
# Out:
# this is my program|

# %%
l = [1,2,3,4,5]

# %%
len(l)
# Out:
# 5

# %% [markdown]
# Above shown are in-built functions which we were using, now quiestion arises how i can create my very own functions `Custom Function`

# %%
def test():
  pass

# %%
def test1():
  print("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
test1()
# Out:
# this is my very very first function

# %%
test1() + "rahul"
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8c003eb2b8d2> in <cell line: 1>()
# ----> 1 test1() + "rahul"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %% [markdown]
# - error because, the function `test1()` is not returning anything thats why it is `NoneType` and we can concatinate `Nonetype` with `str`

# %%
def test2():
  return "this is my fun with return "

# %%
test2()
# Out:
# 'this is my fun with return '

# %%
test2() + "rahul"
# Out:
# 'this is my fun with return rahul'

# %% [markdown]
# - As we can see `test2()` is function which is returning string, so we can perform any premitive functions. on `test1()` it was not possible

# %%
def test3():
  return 1, 4, "myskills", 34.56

# %%
test3()
# Out:
# (1, 4, 'myskills', 34.56)

# %% [markdown]
# - Yes, we can return multiple values a s output

# %%
a = 1,2,3,4,5

# %%
a
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# - `a` is holding mutiple data at a time

# %%
a,b,c,d = 1,2,34.45,True

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 34.45

# %%
d
# Out:
# True

# %% [markdown]
# - `a,b,c,d` a scan hold multiple values in single go

# %%
test3()
# Out:
# (1, 4, 'myskills', 34.56)

# %%
test3()[0]
# Out:
# 1

# %%
test3()[1]
# Out:
# 4

# %%
test3()[2]
# Out:
# 'myskills'

# %% [markdown]
# Q. Why we are using `return` ?
#
# -> At end of day we are looking at an outcome from the function, so yes function needs to return something.

# %%
test3()
# Out:
# (1, 4, 'myskills', 34.56)

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 1

# %%
b
# Out:
# 4

# %%
c
# Out:
# 'myskills'

# %%
d
# Out:
# 34.56

# %%
def test4():
    a = 3*4+5
    return a

# %%
test4()
# Out:
# 17

# %%
type(test4())
# Out:
# int

# %%
def test5(a,b):
    c = a + b
    return c

# %%
test5(a, b)
# Out:
# 5

# %%
test5('rahul', 'shelke')
# Out:
# 'rahulshelke'

# %% [markdown]
# - after passing string as input argument it returned the string concatination

# %%
test5([1,2,3,4], [4,5,6,7,8])
# Out:
# [1, 2, 3, 4, 4, 5, 6, 7, 8]

# %% [markdown]
# - after passing list as input argument it returned the list concatination
#
# - so depending upon what logic we have returned in side the function body and what type of input i have provided to the function that matters

# %% [markdown]
# Q. what if i want to send `b` first and `a` after it ?

# %%
test5(b = "rahul ", a = "shelke")
# Out:
# 'shelkerahul '

# %% [markdown]
# - it has taken values irrespective of order we passed

# %%
l = [1,2,3,4,5 , "rahul", "pwskills", [1,2,3,34,45]]

# %%
# create a function which will take list as a input and give me a final list with all the numeric value

# %%
def test6(a):
  n = []
  for i in a:
    if type(i) == int or type(i) == float:
      n.append(i)
  return n

# %%
test6(a=l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'rahul', 'pwskills', [1, 2, 3, 34, 45]]

# %%
def test7(a):
  n = []
  for i in a:
    if type(i) == list:
      for j in i:
        if type(j) == int or type(j) == float:
          n.append(j)
    else:
      if type(i) == int or type(i) == float:
          n.append(i)
  return n

# %%
test7(l)
# Out:
# [1, 2, 3, 4, 5, 1, 2, 3, 34, 45]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'rahul', 'pwskills', [1, 2, 3, 34, 45]]
