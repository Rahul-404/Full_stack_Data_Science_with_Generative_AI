# %% [markdown]
# "Oops" stands for Object-Oriented Programming System

# %% [markdown]
# Why to use oops?

# %%
a = 1

# %%
print(type(a)) # a belongs to class type integer
# Out:
# <class 'int'>

# %%
print(type("myskills")) # it belongs to class string
# Out:
# <class 'str'>

# %%
class test:
  pass

# %%
a = test()

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %% [markdown]
# a belongs to a class test

# %%
class myskills:

  def welcome_msg(self):
    print("welcome to myskills")

# %%
rohan = myskills()

# %%
rohan.welcome_msg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-544556fd0fa5> in <cell line: 1>()
# ----> 1 rohan.welcome_msg()
#
# TypeError: myskills.welcome_msg() takes 0 positional arguments but 1 was given

# %% [markdown]
# - we error because , when ever we create a method inside a class, we should give a pointer to bind that method with class
# - then the class will able to recognize that this method belongs to me

# %%
class myskills:

  def welcome_msg(self):
    print("welcome to myskills")

# %%
rohan = myskills()

# %%
rohan.welcome_msg()
# Out:
# welcome to myskills

# %%
soham = myskills()

# %%
soham.welcome_msg()
# Out:
# welcome to myskills

# %% [markdown]
# - what is would like to pass a data to methods

# %%
a = 1

# %%
b = 2

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %% [markdown]
# - it will happen with help of constructor, will create a constroctur, it will allow us to pass data of different type to class and its methods

# %%
class myskills:

  def __init__(self, phone_number, email_id, student_id):
    # it's in built method / constructir
    self.phone_number = phone_number
    self.email_id = email_id
    self.student_id = student_id

  def return_student_details(self):
    return self.phone_number, self.email_id, self.student_id

# %%
rohan = myskills()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-c43e9a3a66a4> in <cell line: 1>()
# ----> 1 rohan = myskills()
#
# TypeError: myskills.__init__() missing 3 required positional arguments: 'phone_number', 'email_id', and 'student_id'

# %% [markdown]
# - error because we haven't passed input

# %%
sohan = myskills(64465465, "sohan@gmail.com", 102)

# %%
sohan.phone_number
# Out:
# 64465465

# %%
sohan.email_id
# Out:
# 'sohan@gmail.com'

# %%
sohan.student_id
# Out:
# 102

# %%
sohan.return_student_details()
# Out:
# (64465465, 'sohan@gmail.com', 102)

# %%
rohan = myskills(304568412, "rohan@gmail.com", 101)

# %%
rohan.return_student_details()
# Out:
# (304568412, 'rohan@gmail.com', 101)

# %%
rohan.phone_number
# Out:
# 304568412

# %%
rohan.email_id
# Out:
# 'rohan@gmail.com'

# %%
rohan.student_id
# Out:
# 101

# %% [markdown]
# -What is onthe place of `self` if i used `rahul` will that work

# %%
class myskills2:

  def __init__(rahul, phone_number, email_id, student_id):
    # it's in built method / constructir
    rahul.phone_number = phone_number
    rahul.email_id = email_id
    rahul.student_id = student_id

  def return_student_details(rahul):
    return rahul.phone_number, rahul.email_id, rahul.student_id

# %%
rohan = myskills2(57647646, "rohan@gmail.com", 101)

# %%
rohan.return_student_details()
# Out:
# (57647646, 'rohan@gmail.com', 101)

# %% [markdown]
# - it worked, we can use any name as a reference point to refer the class
#
# - `self` is something we don't have to use all the time but we have to use something

# %%
class myskills3:

  def __init__(rahul, phone_number, email_id, student_id):
    # it's in built method / constructir
    rahul.phone_number = phone_number
    rahul.email_id = email_id
    rahul.student_id = student_id

  def return_student_details(rahul):
    return rahul.phone_number, rahul.email_id, rahul.student_id

# %%
rohan = myskills2(57647646, "rohan@gmail.com", 101)

# %% [markdown]
# Q. `rohan.phone_number` refering to which phoen number this `rahul.phone_number`or this `phone_number`?

# %%
rohan.phone_number
# Out:
# 57647646

# %% [markdown]
# Let's change the variable names and then check

# %%
class myskills3:

  def __init__(rahul, phone_number, email_id, student_id):
    # it's in built method / constructir
    rahul.phone_number1 = phone_number
    rahul.email_id = email_id
    rahul.student_id = student_id

  def return_student_details(rahul):
    return rahul.phone_number, rahul.email_id, rahul.student_id

# %%
rohan = myskills3(57647646, "rohan@gmail.com", 101)

# %%
rohan.phone_number1
# Out:
# 57647646

# %%
rohan.phone_number
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-e29175df2616> in <cell line: 1>()
# ----> 1 rohan.phone_number
#
# AttributeError: 'myskills3' object has no attribute 'phone_number'

# %% [markdown]
# - it is refering to `rahul.phone_number1`

# %% [markdown]
# -if we call `rohan.return_student_details()` are we getting error or what?

# %%
rohan.return_student_details()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-c5a6677fe2e7> in <cell line: 1>()
# ----> 1 rohan.return_student_details()
#
# <ipython-input-52-95f097443c6a> in return_student_details(rahul)
#       8
#       9   def return_student_details(rahul):
# ---> 10     return rahul.phone_number, rahul.email_id, rahul.student_id
#
# AttributeError: 'myskills3' object has no attribute 'phone_number'

# %% [markdown]
# - we got error, because class don't know `phoen_numebr` is aknowleged only `phone_number1`
