# %%
s = "rahul"

# %%
s[1]
# Out:
# 'a'

# %%
s[-4]
# Out:
# 'a'

# %%
l = [2,3,4,5,6,6,'rahul', "myskills", True, 4+7j]

# %%
type(l)
# Out:
# list

# %%
l[7], l[-3]
# Out:
# ('myskills', 'myskills')

# %%
s
# Out:
# 'rahul'

# %%
l
# Out:
# [2, 3, 4, 5, 6, 6, 'rahul', 'myskills', True, (4+7j)]

# %%
l[6]
# Out:
# 'rahul'

# %%
l[6] = 100

# %%
l
# Out:
# [2, 3, 4, 5, 6, 6, 100, 'myskills', True, (4+7j)]

# %%
s
# Out:
# 'rahul'

# %%
s[2]
# Out:
# 'h'

# %%
s[2] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c1dcb891647a> in <cell line: 1>()
# ----> 1 s[2] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'raaul'

# %%
s
# Out:
# 'raaul'
