# %%
print("Hello to the programming world")
# Out:
# Hello to the programming world

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b = 34.4565

# %%
b
# Out:
# 34.4565

# %%
type(b)
# Out:
# float

# %%
c = "rahul"

# %%
c1 = 'rahul'

# %%
type(c)
# Out:
# str

# %%
type(c1)
# Out:
# str

# %%
d = True

# %%
type(d)
# Out:
# bool

# %%
d1 = False

# %%
type(d1)
# Out:
# bool

# %%
True - False
# Out:
# 1

# %%
False - True
# Out:
# -1

# %%
True * False
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-f8487d9d0863> in <cell line: 1>()
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
e = 4+7j

# %%
type(e)
# Out:
# complex

# %%
e
# Out:
# (4+7j)

# %%
e.real
# Out:
# 4.0

# %%
# This is extracting a imag part of my complex number
e.imag
# Out:
# 7.0

# %%
e.conjugate()
# Out:
# (4-7j)

# %%
"""trhis is extracting a
imag part of
my complex number"""
e.imag
# Out:
# 7.0

# %%
a = 10

# %%
1a = 10
# Out:
#   File "<ipython-input-36-1be9f8edb7cd>", line 1
#     1a = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
11 = 10
# Out:
#   File "<ipython-input-37-bb9039d96a78>", line 1
#     11 = 10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
@error = 34
# Out:
#   File "<ipython-input-39-f351fa9ba60a>", line 1
#     @error = 34
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#fdsf = 345

# %%
# %fdsfa = 3434
# Out:
# UsageError: Line magic function `%fdsfa` not found.

# %%
_a = 34

# %%
_a
# Out:
# 34

# %%
a1 = 4554

# %%
a& = 45
# Out:
#   File "<ipython-input-46-51a91f96c727>", line 1
#     a& = 45
#        ^
# SyntaxError: invalid syntax

# %%
a% = 234
# Out:
#   File "<ipython-input-50-12db2ce45d9a>", line 1
#     a% = 234
#        ^
# SyntaxError: invalid syntax

# %%
rahul = 345

# %%
rahul
# Out:
# 345

# %%
s = "Rahul"

# %%
a = 10

# %%
a + s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-4626706d70eb> in <cell line: 1>()
# ----> 1 a + s
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
s + a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-105bd19b3ee8> in <cell line: 1>()
# ----> 1 s + a
#
# TypeError: can only concatenate str (not "int") to str

# %%
'10 ' + s
# Out:
# '10 Rahul'

# %%
a = 10

# %%
str(a) + s
# Out:
# '10Rahul'

# %%
b = input()
# Out:
# 654364

# %%
b
# Out:
# '654364'

# %%
type(b)
# Out:
# str

# %%
c = int(input())
# Out:
# 64666555664

# %%
type(c)
# Out:
# int
